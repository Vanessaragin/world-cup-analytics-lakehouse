# %%
import pandas as pd

# %%
matches = pd.read_csv(
    "../data/bronze/openfootball/bronze_matches.csv"
)

team_stats = pd.read_csv(
    "../data/bronze/openfootball/bronze_team_match_stats.csv"
)

goals = pd.read_csv(
    "../data/bronze/openfootball/bronze_goals.csv"
)

# %%
matches[
    ["year", "has_score", "has_goals_events"]
].groupby("year").sum()
# Out:
#       has_score  has_goals_events
# year
# 1930         18                18
# 1934         17                17
# 1938         18                18
# 1950         22                22
# 1954         26                 0
# 1958         35                 0
# 1962         32                 0
# 1966         32                 0
# 1970         32                 0
# 1974         38                 0
# 1978         38                 0
# 1982         52                 0
# 1986         52                 0
# 1990         52                 4
# 1994         52                 0
# 1998         64                 0
# 2002         64                 0
# 2006         64                 4
# 2010         64                 0
# 2014         64                57
# 2018         64                63
# 2022         64                57
# 2026          0                 0

# %%
team_stats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1928 entries, 0 to 1927
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         1928 non-null   str
#  1   year             1928 non-null   int64
#  2   cup_name         1928 non-null   str
#  3   round            1928 non-null   str
#  4   date             1928 non-null   str
#  5   team             1928 non-null   str
#  6   opponent         1928 non-null   str
#  7   goals_for        1928 non-null   int64
#  8   goals_against    1928 non-null   int64
#  9   goal_difference  1928 non-null   int64
#  10  is_winner        1928 non-null   bool
#  11  is_draw          1928 non-null   bool
#  12  is_loser         1928 non-null   bool
#  13  match_played     1928 non-null   bool
# dtypes: bool(4), int64(4), str(6)
# memory usage: 158.3 KB

# %%
matches.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1069 entries, 0 to 1068
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   match_id           1069 non-null   str
#  1   match_num          30 non-null     float64
#  2   year               1069 non-null   int64
#  3   cup_name           1069 non-null   str
#  4   round              1069 non-null   str
#  5   date               1069 non-null   str
#  6   time               360 non-null    str
#  7   team1              1069 non-null   str
#  8   team2              1069 non-null   str
#  9   team1_score_ft     964 non-null    float64
#  10  team2_score_ft     964 non-null    float64
#  11  total_goals_ft     964 non-null    float64
#  12  team1_score_ht     256 non-null    float64
#  13  team2_score_ht     256 non-null    float64
#  14  total_goals_ht     256 non-null    float64
#  15  team1_score_et     73 non-null     float64
# ...

# %%
goals.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2720 entries, 0 to 2719
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match_id     2720 non-null   str
#  1   year         2720 non-null   int64
#  2   team         2720 non-null   str
#  3   opponent     2720 non-null   str
#  4   player_name  2720 non-null   str
#  5   minute       841 non-null    float64
#  6   offset       56 non-null     float64
#  7   penalty      2720 non-null   bool
#  8   owngoal      2720 non-null   bool
#  9   goal_side    2720 non-null   str
#  10  goal_source  2720 non-null   str
# dtypes: bool(2), float64(2), int64(1), str(6)
# memory usage: 196.7 KB

# %%
team_stats.isnull().sum()
# Out:
# match_id           0
# year               0
# cup_name           0
# round              0
# date               0
# team               0
# opponent           0
# goals_for          0
# goals_against      0
# goal_difference    0
# is_winner          0
# is_draw            0
# is_loser           0
# match_played       0
# dtype: int64

# %%
matches.isnull().sum()
# Out:
# match_id                0
# match_num            1039
# year                    0
# cup_name                0
# round                   0
# date                    0
# time                  709
# team1                   0
# team2                   0
# team1_score_ft        105
# team2_score_ft        105
# total_goals_ft        105
# team1_score_ht        813
# team2_score_ht        813
# total_goals_ht        813
# team1_score_et        996
# team2_score_et        996
# total_goals_et        996
# team1_score_final     105
# team2_score_final     105
# total_goals_final     105
# team1_score_p        1034
# team2_score_p        1034
# total_goals_p        1034
# group                 290
# ground                  0
# status                  0
# has_score               0
# has_goals_events        0
# dtype: int64

# %%
goals.isnull().sum()
# Out:
# match_id          0
# year              0
# team              0
# opponent          0
# player_name       0
# minute         1879
# offset         2664
# penalty           0
# owngoal           0
# goal_side         0
# goal_source       0
# dtype: int64

# %%
matches.duplicated().sum()
# Out:
# np.int64(0)

# %%
goals.duplicated().sum()
# Out:
# np.int64(915)

# %%
matches[
    (
        matches["team1_score"]
        + matches["team2_score"]
    ) != matches["total_goals"]
][
    [
        "match_id",
        "year",
        "team1",
        "team2",
        "team1_score",
        "team2_score",
        "total_goals"
    ]
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/portfolio-data-engineering/projeto-01-world-cup-analytics-lakehouse/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
matches["match_played"] = (
    matches["team1_score"].notna()
)

# %%
matches.fillna(0)

# %%
matches[["team1_score","team2_score","match_played"]].head()

# %%
matches["match_played"].value_counts()

# %% [markdown]
# Quantos jogos existem?

# %%
matches.shape

# %% [markdown]
# Quantos gols existem?

# %%
len(goals)

# %% [markdown]
# Quantas Copas existem?

# %%
sorted(matches["year"].unique())

# %% [markdown]
# Qual Copa teve mais jogos?

# %%
matches.groupby("year").size()

# %% [markdown]
# Qual Copa teve mais gols?

# %%
goals.groupby("year").size().sort_values(ascending=False)

# %%
goals["year"].drop_duplicates()

# %%
goals["year"].value_counts().sort_index()
